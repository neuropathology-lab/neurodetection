# %%
from neurodetection import detectNeurons

if __name__ == "__main__":

    input_dir   = "D:/klara_files/test_neurodetection/photos_raw"
    out_dir     = "D:/klara_files/test_neurodetection/results"
    pixel_size  = 0.227 * 1.5

    detectNeurons(
        input_dir,
        out_dir,
        pixel_size,
        plot_results="detailed"
    )
